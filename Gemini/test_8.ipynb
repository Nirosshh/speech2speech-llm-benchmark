# %%
# !pip install --quiet google-generativeai

# %%
import time, google.generativeai as genai
from google.generativeai.types import HarmCategory, HarmBlockThreshold

# %%
# --- Configure (use your env var or paste the key) ---
# import os; genai.configure(api_key=os.environ["GEMINI_API_KEY"])
genai.configure(api_key="AIzaSyBX9N8xcO96-xNj88XejWGrqJ_EHZ2R0ls")   # replace if not using env var

# %%
model = genai.GenerativeModel("gemini-1.5-flash")  # or "gemini-1.5-pro"

# %%
prompt = "Hi"

# %%
prompt = "why latency of the reslponse vary each time?"

# %%
# --- Start request & measure TTFT/TTFX ---
ttft = None
start = time.time()              # request start (for TTFT)
resp = model.generate_content(
    prompt,
    stream=True,
    safety_settings={HarmCategory.HARM_CATEGORY_HATE_SPEECH: HarmBlockThreshold.BLOCK_NONE}
)

full = []
for chunk in resp:
    text = chunk.text or ""
    if not text:
        continue
    if ttft is None:
        ttft = time.time() - start
        print(f"\nTTFT: {ttft:.3f}s\n")
    full.append(text)
    print(text, end="", flush=True)

# finished streaming
ttfx = time.time() - start
full_text = "".join(full)

print("\n\n" + "-"*50)
print(f"TTFT (first token): {ttft:.3f}s")
print(f"TTFX (final token): {ttfx:.3f}s")
print(f"Output chars: {len(full_text)}")
# Out:
# TTFT: 0.527s
#
# The latency of a response varies each time due to a multitude of factors, all interacting in complex ways.  Here are some key contributors:
#
# **Network-Related Factors:**
#
# * **Network Congestion:**  The most significant factor.  Network paths are shared resources.  High traffic (many users uploading/downloading simultaneously, network bottlenecks) leads to increased latency. This is especially true during peak usage times.
# * **Routing Changes:**  Network routers dynamically choose the best path for data packets.  These paths can change based on network conditions, leading to variations in travel time.
# * **Wireless Interference:**  For Wi-Fi connections, interference from other devices (microwaves, Bluetooth devices, other Wi-Fi networks) can significantly impact latency.  Physical obstructions and distance also play a role.
# * **Server Load:**  The server responding to the request might be overloaded with requests.  More requests mean longer wait times for each individual request to be processed.
# * **Geographic Distance:**  The further the client is from the server, the longer it takes for data to travel.  This is a fundamental limitation of the speed of light.
# * **Packet Loss and Re-transmission:**  Data packets can be lost during transmission.  Protocols like TCP require re-transmission of lost packets, adding significant delay.
# * **Quality of Service (QoS):** Networks often prioritize certain types of traffic over others (e.g., VoIP calls over web browsing).  If your request is not prioritized, it might experience higher latency.
# * **Intermediary Devices:** Firewalls, proxies, and load balancers can introduce small but noticeable delays.
#
# **Application-Specific Factors:**
#
# * **Server-Side Processing:** The time it takes for the server to process your request (database queries, complex calculations, etc.) can vary based on the current load and the complexity of the request.
# * **Database Performance:**  If the response involves database queries, the speed of the database and the complexity of the query will influence latency.
# * **Application Bugs:** Bugs in the application itself can lead to unpredictable performance and latency spikes.
# * **Caching:**  If the response is cached, latency will be much lower than if it needs to be computed from scratch.  Cache misses introduce significant delays.
#
#
# **Client-Side Factors:**
#
# * **Client's Processing Power:**  The client's computer needs to process the received data.  A slower computer will result in slightly higher perceived latency.
# * **Client's Network Conditions:**  The client's own network conditions (congestion, interference) affect upload and download speeds.
#
# In summary, latency isn't a fixed value but a highly dynamic quantity influenced by a multitude of factors at various points in the network and application stack.  It's often unpredictable, and measuring it multiple times will invariably reveal variations.
#
#
# --------------------------------------------------
# TTFT (first token): 0.527s
# TTFX (final token): 4.322s
# Output chars: 2915
