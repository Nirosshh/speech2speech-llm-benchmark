# %%
# !pip install openai
# Out:
# Collecting openai
#   Downloading openai-1.102.0-py3-none-any.whl.metadata (29 kB)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\nirosh\onedrive\desktop\project\coding\.venv\lib\site-packages (from openai) (4.10.0)
# Collecting distro<2,>=1.7.0 (from openai)
#   Downloading distro-1.9.0-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\nirosh\onedrive\desktop\project\coding\.venv\lib\site-packages (from openai) (0.28.1)
# Collecting jiter<1,>=0.4.0 (from openai)
#   Downloading jiter-0.10.0-cp313-cp313-win_amd64.whl.metadata (5.3 kB)
# Collecting pydantic<3,>=1.9.0 (from openai)
#   Downloading pydantic-2.11.7-py3-none-any.whl.metadata (67 kB)
# Requirement already satisfied: sniffio in c:\users\nirosh\onedrive\desktop\project\coding\.venv\lib\site-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in c:\users\nirosh\onedrive\desktop\project\coding\.venv\lib\site-packages (from openai) (4.67.1)
# Requirement already satisfied: typing-extensions<5,>=4.11 in c:\users\nirosh\onedrive\desktop\project\coding\.venv\lib\site-packages (from openai) (4.15.0)
# Requirement already satisfied: idna>=2.8 in c:\users\nirosh\onedrive\desktop\project\coding\.venv\lib\site-packages (from anyio<5,>=3.5.0->openai) (3.10)
# Requirement already satisfied: certifi in c:\users\nirosh\onedrive\desktop\project\coding\.venv\lib\site-packages (from httpx<1,>=0.23.0->openai) (2025.8.3)
# Requirement already satisfied: httpcore==1.* in c:\users\nirosh\onedrive\desktop\project\coding\.venv\lib\site-packages (from httpx<1,>=0.23.0->openai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\nirosh\onedrive\desktop\project\coding\.venv\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.16.0)
# Collecting annotated-types>=0.6.0 (from pydantic<3,>=1.9.0->openai)
#   Downloading annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.33.2 (from pydantic<3,>=1.9.0->openai)
#   Downloading pydantic_core-2.33.2-cp313-cp313-win_amd64.whl.metadata (6.9 kB)
# Collecting typing-inspection>=0.4.0 (from pydantic<3,>=1.9.0->openai)
#   Downloading typing_inspection-0.4.1-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: colorama in c:\users\nirosh\onedrive\desktop\project\coding\.venv\lib\site-packages (from tqdm>4->openai) (0.4.6)
# Downloading openai-1.102.0-py3-none-any.whl (812 kB)
#    ---------------------------------------- 0.0/812.0 kB ? eta -:--:--
#    ------------ --------------------------- 262.1/812.0 kB ? eta -:--:--
#    ------------ --------------------------- 262.1/812.0 kB ? eta -:--:--
#    ---------------------------------------- 812.0/812.0 kB 1.4 MB/s  0:00:00
# Downloading distro-1.9.0-py3-none-any.whl (20 kB)
# Downloading jiter-0.10.0-cp313-cp313-win_amd64.whl (205 kB)
# Downloading pydantic-2.11.7-py3-none-any.whl (444 kB)
# Downloading pydantic_core-2.33.2-cp313-cp313-win_amd64.whl (2.0 MB)
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/2.0 MB ? eta -:--:--
#    ---------- ----------------------------- 0.5/2.0 MB 1.7 MB/s eta 0:00:01
#    --------------------- ------------------ 1.0/2.0 MB 1.9 MB/s eta 0:00:01
#    -------------------------- ------------- 1.3/2.0 MB 1.8 MB/s eta 0:00:01
#    ---------------------------------------- 2.0/2.0 MB 2.0 MB/s  0:00:01
# Downloading annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Downloading typing_inspection-0.4.1-py3-none-any.whl (14 kB)
# Installing collected packages: typing-inspection, pydantic-core, jiter, distro, annotated-types, pydantic, openai
#
#    ----------------- ---------------------- 3/7 [distro]
#    ---------------------------- ----------- 5/7 [pydantic]
#    ---------------------------- ----------- 5/7 [pydantic]
#    ---------------------------- ----------- 5/7 [pydantic]
#    ---------------------------- ----------- 5/7 [pydantic]
#    ---------------------------- ----------- 5/7 [pydantic]
#    ---------------------------- ----------- 5/7 [pydantic]
#    ---------------------------- ----------- 5/7 [pydantic]
#    ---------------------------- ----------- 5/7 [pydantic]
#    ---------------------------- ----------- 5/7 [pydantic]
#    ---------------------------- ----------- 5/7 [pydantic]
#    ---------------------------- ----------- 5/7 [pydantic]
#    ---------------------------- ----------- 5/7 [pydantic]
#    ---------------------------------- ----- 6/7 [openai]
#    ---------------------------------- ----- 6/7 [openai]
#    ---------------------------------- ----- 6/7 [openai]
#    ---------------------------------- ----- 6/7 [openai]
#    ---------------------------------- ----- 6/7 [openai]
#    ---------------------------------- ----- 6/7 [openai]
#    ---------------------------------- ----- 6/7 [openai]
#    ---------------------------------- ----- 6/7 [openai]
#    ---------------------------------- ----- 6/7 [openai]
#    ---------------------------------- ----- 6/7 [openai]
#    ---------------------------------- ----- 6/7 [openai]
#    ---------------------------------- ----- 6/7 [openai]
#    ---------------------------------- ----- 6/7 [openai]
#    ---------------------------------- ----- 6/7 [openai]
#    ---------------------------------- ----- 6/7 [openai]
#    ---------------------------------- ----- 6/7 [openai]
#    ---------------------------------- ----- 6/7 [openai]
#    ---------------------------------- ----- 6/7 [openai]
#    ---------------------------------- ----- 6/7 [openai]
#    ---------------------------------- ----- 6/7 [openai]
#    ---------------------------------- ----- 6/7 [openai]
#    ---------------------------------- ----- 6/7 [openai]
#    ---------------------------------- ----- 6/7 [openai]
#    ---------------------------------- ----- 6/7 [openai]
#    ---------------------------------- ----- 6/7 [openai]
#    ---------------------------------- ----- 6/7 [openai]
#    ---------------------------------- ----- 6/7 [openai]
#    ---------------------------------- ----- 6/7 [openai]
#    ---------------------------------- ----- 6/7 [openai]
#    ---------------------------------- ----- 6/7 [openai]
#    ---------------------------------- ----- 6/7 [openai]
#    ---------------------------------- ----- 6/7 [openai]
#    ---------------------------------- ----- 6/7 [openai]
#    ---------------------------------- ----- 6/7 [openai]
#    ---------------------------------- ----- 6/7 [openai]
#    ---------------------------------- ----- 6/7 [openai]
#    ---------------------------------- ----- 6/7 [openai]
#    ---------------------------------- ----- 6/7 [openai]
#    ---------------------------------- ----- 6/7 [openai]
#    ---------------------------------- ----- 6/7 [openai]
#    ---------------------------------- ----- 6/7 [openai]
#    ---------------------------------- ----- 6/7 [openai]
#    ---------------------------------- ----- 6/7 [openai]
#    ---------------------------------- ----- 6/7 [openai]
#    ---------------------------------- ----- 6/7 [openai]
#    ---------------------------------- ----- 6/7 [openai]
#    ---------------------------------- ----- 6/7 [openai]
#    ---------------------------------- ----- 6/7 [openai]
#    ---------------------------------- ----- 6/7 [openai]
#    ---------------------------------- ----- 6/7 [openai]
#    ---------------------------------- ----- 6/7 [openai]
#    ---------------------------------- ----- 6/7 [openai]
#    ---------------------------------- ----- 6/7 [openai]
#    ---------------------------------- ----- 6/7 [openai]
#    ---------------------------------- ----- 6/7 [openai]
#    ---------------------------------- ----- 6/7 [openai]
#    ---------------------------------- ----- 6/7 [openai]
#    ---------------------------------- ----- 6/7 [openai]
#    ---------------------------------- ----- 6/7 [openai]
#    ---------------------------------- ----- 6/7 [openai]
#    ---------------------------------- ----- 6/7 [openai]
#    ---------------------------------- ----- 6/7 [openai]
#    ---------------------------------- ----- 6/7 [openai]
#    ---------------------------------- ----- 6/7 [openai]
#    ---------------------------------- ----- 6/7 [openai]
#    ---------------------------------- ----- 6/7 [openai]
#    ---------------------------------- ----- 6/7 [openai]
#    ---------------------------------------- 7/7 [openai]
#
# Successfully installed annotated-types-0.7.0 distro-1.9.0 jiter-0.10.0 openai-1.102.0 pydantic-2.11.7 pydantic-core-2.33.2 typing-inspection-0.4.1

# %%
from openai import OpenAI
from openai import OpenAI

client = OpenAI(api_key="SK_REDACTED")


response = client.responses.create(
    model="gpt-5",
    input="Write a one-sentence bedtime story about a unicorn."
)

print(response.output_text)
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[5], line 7
#       2 from openai import OpenAI
#       4 client = OpenAI(api_key="SK_REDACTED")
# ----> 7 response = client.responses.create(
#       8     model="gpt-5",
#       9     input="Write a one-sentence bedtime story about a unicorn."
#      10 )
#      12 print(response.output_text)
#
# File ~\OneDrive\Desktop\Project\Coding\.venv\Lib\site-packages\openai\resources\responses\responses.py:820, in Responses.create(self, background, conversation, include, input, instructions, max_output_tokens, max_tool_calls, metadata, model, parallel_tool_calls, previous_response_id, prompt, prompt_cache_key, reasoning, safety_identifier, service_tier, store, stream, stream_options, temperature, text, tool_choice, tools, top_logprobs, top_p, truncation, user, extra_headers, extra_query, extra_body, timeout)
#     783 def create(
#     784     self,
#     785     *,
#    (...)    818     timeout: float | httpx.Timeout | None | NotGiven = NOT_GIVEN,
#     819 ) -> Response | Stream[ResponseStreamEvent]:
# --> 820     return self._post(
#     821         "/responses",
#     822         body=maybe_transform(
#     823             {
#     824                 "background": background,
#     825                 "conversation": conversation,
#     826                 "include": include,
#     827                 "input": input,
#     828                 "instructions": instructions,
#     829                 "max_output_tokens": max_output_tokens,
#     830                 "max_tool_calls": max_tool_calls,
#     831                 "metadata": metadata,
#     832                 "model": model,
#     833                 "parallel_tool_calls": parallel_tool_calls,
#     834                 "previous_response_id": previous_response_id,
#     835                 "prompt": prompt,
#     836                 "prompt_cache_key": prompt_cache_key,
#     837                 "reasoning": reasoning,
#     838                 "safety_identifier": safety_identifier,
#     839                 "service_tier": service_tier,
#     840                 "store": store,
#     841                 "stream": stream,
#     842                 "stream_options": stream_options,
#     843                 "temperature": temperature,
#     844                 "text": text,
#     845                 "tool_choice": tool_choice,
#     846                 "tools": tools,
#     847                 "top_logprobs": top_logprobs,
#     848                 "top_p": top_p,
#     849                 "truncation": truncation,
#     850                 "user": user,
#     851             },
#     852             response_create_params.ResponseCreateParamsStreaming
#     853             if stream
#     854             else response_create_params.ResponseCreateParamsNonStreaming,
#     855         ),
#     856         options=make_request_options(
#     857             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     858         ),
#     859         cast_to=Response,
#     860         stream=stream or False,
#     861         stream_cls=Stream[ResponseStreamEvent],
#     862     )
#
# File ~\OneDrive\Desktop\Project\Coding\.venv\Lib\site-packages\openai\_base_client.py:1259, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1245 def post(
#    1246     self,
#    1247     path: str,
#    (...)   1254     stream_cls: type[_StreamT] | None = None,
#    1255 ) -> ResponseT | _StreamT:
#    1256     opts = FinalRequestOptions.construct(
#    1257         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1258     )
# -> 1259     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~\OneDrive\Desktop\Project\Coding\.venv\Lib\site-packages\openai\_base_client.py:1047, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1044             err.response.read()
#    1046         log.debug("Re-raising status error")
# -> 1047         raise self._make_status_error_from_response(err.response) from None
#    1049     break
#    1051 assert response is not None, "could not resolve response (should never happen)"
#
# RateLimitError: Error code: 429 - {'error': {'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://platform.openai.com/docs/guides/error-codes/api-errors.', 'type': 'insufficient_quota', 'param': None, 'code': 'insufficient_quota'}}
