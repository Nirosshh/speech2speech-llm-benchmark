# %% [markdown]
# Step 1) Install & set up

# %%
pip install --upgrade openai
# Out:
# Requirement already satisfied: openai in c:\users\nirosh\anaconda3\envs\cits5508\lib\site-packages (1.107.0)
# Collecting openai
#   Downloading openai-1.107.3-py3-none-any.whl.metadata (29 kB)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\nirosh\anaconda3\envs\cits5508\lib\site-packages (from openai) (4.8.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\nirosh\anaconda3\envs\cits5508\lib\site-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\nirosh\anaconda3\envs\cits5508\lib\site-packages (from openai) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in c:\users\nirosh\anaconda3\envs\cits5508\lib\site-packages (from openai) (0.10.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in c:\users\nirosh\anaconda3\envs\cits5508\lib\site-packages (from openai) (2.11.7)
# Requirement already satisfied: sniffio in c:\users\nirosh\anaconda3\envs\cits5508\lib\site-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in c:\users\nirosh\anaconda3\envs\cits5508\lib\site-packages (from openai) (4.66.6)
# Requirement already satisfied: typing-extensions<5,>=4.11 in c:\users\nirosh\anaconda3\envs\cits5508\lib\site-packages (from openai) (4.12.2)
# Requirement already satisfied: idna>=2.8 in c:\users\nirosh\anaconda3\envs\cits5508\lib\site-packages (from anyio<5,>=3.5.0->openai) (3.10)
# Requirement already satisfied: certifi in c:\users\nirosh\anaconda3\envs\cits5508\lib\site-packages (from httpx<1,>=0.23.0->openai) (2025.1.31)
# Requirement already satisfied: httpcore==1.* in c:\users\nirosh\anaconda3\envs\cits5508\lib\site-packages (from httpx<1,>=0.23.0->openai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\nirosh\anaconda3\envs\cits5508\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\nirosh\anaconda3\envs\cits5508\lib\site-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\users\nirosh\anaconda3\envs\cits5508\lib\site-packages (from pydantic<3,>=1.9.0->openai) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\nirosh\anaconda3\envs\cits5508\lib\site-packages (from pydantic<3,>=1.9.0->openai) (0.4.1)
# Requirement already satisfied: colorama in c:\users\nirosh\anaconda3\envs\cits5508\lib\site-packages (from tqdm>4->openai) (0.4.6)
# Downloading openai-1.107.3-py3-none-any.whl (947 kB)
#    ---------------------------------------- 0.0/947.6 kB ? eta -:--:--
#    ---------------------- ----------------- 524.3/947.6 kB 5.6 MB/s eta 0:00:01
#    ---------------------------------------- 947.6/947.6 kB 3.4 MB/s eta 0:00:00
# Installing collected packages: openai
#   Attempting uninstall: openai
#     Found existing installation: openai 1.107.0
#     Uninstalling openai-1.107.0:
#       Successfully uninstalled openai-1.107.0
# Successfully installed openai-1.107.3
# Note: you may need to restart the kernel to use updated packages.

# %%
from dotenv import load_dotenv
import os
from openai import OpenAI

# load keys.env
load_dotenv("keys.env")

# check that the OpenAI key is visible
print("OPENAI_API_KEY exists?", bool(os.getenv("OPENAI_API_KEY")))
# Out:
# OPENAI_API_KEY exists? True

# %%
client = OpenAI(api_key=os.environ["OPENAI_API_KEY"])

# %%
# list first 5 models to confirm connection
for m in client.models.list().data[:5]:
    print("-", m.id)
# Out:
# ---------------------------------------------------------------------------
# AuthenticationError                       Traceback (most recent call last)
# Cell In[9], line 2
#       1 # list first 5 models to confirm connection
# ----> 2 for m in client.models.list().data[:5]:
#       3     print("-", m.id)
#
# File c:\Users\nirosh\anaconda3\envs\cits5508\Lib\site-packages\openai\resources\models.py:91, in Models.list(self, extra_headers, extra_query, extra_body, timeout)
#      77 def list(
#      78     self,
#      79     *,
#    (...)
#      85     timeout: float | httpx.Timeout | None | NotGiven = NOT_GIVEN,
#      86 ) -> SyncPage[Model]:
#      87     """
#      88     Lists the currently available models, and provides basic information about each
#      89     one such as the owner and availability.
#      90     """
# ---> 91     return self._get_api_list(
#      92         "/models",
#      93         page=SyncPage[Model],
#      94         options=make_request_options(
#      95             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#      96         ),
#      97         model=Model,
#      98     )
#
# File c:\Users\nirosh\anaconda3\envs\cits5508\Lib\site-packages\openai\_base_client.py:1308, in SyncAPIClient.get_api_list(self, path, model, page, body, options, method)
#    1297 def get_api_list(
#    1298     self,
#    1299     path: str,
#    (...)
#    1305     method: str = "get",
#    1306 ) -> SyncPageT:
#    1307     opts = FinalRequestOptions.construct(method=method, url=path, json_data=body, **options)
# -> 1308     return self._request_api_list(model, page, opts)
#
# File c:\Users\nirosh\anaconda3\envs\cits5508\Lib\site-packages\openai\_base_client.py:1159, in SyncAPIClient._request_api_list(self, model, page, options)
#    1155     return resp
#    1157 options.post_parser = _parser
# -> 1159 return self.request(page, options, stream=False)
#
# File c:\Users\nirosh\anaconda3\envs\cits5508\Lib\site-packages\openai\_base_client.py:1047, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1044             err.response.read()
#    1046         log.debug("Re-raising status error")
# -> 1047         raise self._make_status_error_from_response(err.response) from None
#    1049     break
#    1051 assert response is not None, "could not resolve response (should never happen)"
#
# AuthenticationError: Error code: 401 - {'error': {'message': 'Incorrect API key provided: sk-svcac***********************************************************************************************************************************************************ZjMA. You can find your API key at https://platform.openai.com/account/api-keys.', 'type': 'invalid_request_error', 'param': None, 'code': 'invalid_api_key'}}
